# %%
#importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#importing the dataset
dataset=pd.read_csv('Churn_Modelling.csv')
X=dataset.iloc[:,3:13].values
Y=dataset.iloc[:,13].values


from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
labelencoder_1 = LabelEncoder()
X[:, 1] = labelencoder_1.fit_transform(X[:, 1])
labelencoder_1 = LabelEncoder()
X[:, 2] = labelencoder_1.fit_transform(X[:, 2])

transformer = ColumnTransformer(
    transformers=[
        ("Geography",        # Just a name
         OneHotEncoder(), # The transformer class
         [1]            # The column(s) to be applied on.
         )
    ], remainder='passthrough'
)
X = transformer.fit_transform(X)

# Avoiding the Dummy Variable Trap
X = X[:, 1:]

#Divide the dataset into Training and Test Data Set
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train,Y_test = train_test_split(X,Y,test_size=0.2, random_state=0)

#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

#MAKE ANN WORK

#importing libraries
import keras
from keras.models import Sequential
from keras.layers import Dense

#Initialse ANN
classifier = Sequential()

#Adding input layer as well as hidden layer
classifier.add(Dense(units=6, kernel_initializer='uniform', activation='relu', input_dim=11))

#Adding one more hidden layer
classifier.add(Dense(units=6, kernel_initializer='uniform', activation='relu'))

#Adding output layer
classifier.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))

# ANN compilation
classifier.compile(optimizer='adam', loss = 'binary_crossentropy', metrics= ['accuracy'])

#Fitting ANN to training set
classifier.fit(X_train, Y_train, batch_size=10, nb_epoch=100)

#Predicting results
y_pred=classifier.predict(X_test)
y_pred=(y_pred>0.5)


#Confusion matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
print(cm)
# Out:
# Using TensorFlow backend.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:65: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Epoch 1/100
# 8000/8000 [==============================] - 1s 141us/step - loss: 0.5119 - accuracy: 0.7960
# Epoch 2/100
# 8000/8000 [==============================] - 1s 93us/step - loss: 0.4244 - accuracy: 0.8148
# Epoch 3/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.4163 - accuracy: 0.8226
# Epoch 4/100
# 8000/8000 [==============================] - 1s 94us/step - loss: 0.4082 - accuracy: 0.8280
# Epoch 5/100
# 8000/8000 [==============================] - 1s 92us/step - loss: 0.3987 - accuracy: 0.8286
# Epoch 6/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3906 - accuracy: 0.8306
# Epoch 7/100
# 8000/8000 [==============================] - 1s 94us/step - loss: 0.3842 - accuracy: 0.8303
# Epoch 8/100
# 8000/8000 [==============================] - 1s 94us/step - loss: 0.3793 - accuracy: 0.8338
# Epoch 9/100
# 8000/8000 [==============================] - 1s 111us/step - loss: 0.3749 - accuracy: 0.8400
# Epoch 10/100
# 8000/8000 [==============================] - 1s 143us/step - loss: 0.3708 - accuracy: 0.8445
# Epoch 11/100
# 8000/8000 [==============================] - 1s 94us/step - loss: 0.3685 - accuracy: 0.8451
# Epoch 12/100
# 8000/8000 [==============================] - 1s 93us/step - loss: 0.3658 - accuracy: 0.8501
# Epoch 13/100
# 8000/8000 [==============================] - 1s 95us/step - loss: 0.3637 - accuracy: 0.8512
# Epoch 14/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3616 - accuracy: 0.8525
# Epoch 15/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3598 - accuracy: 0.8526
# Epoch 16/100
# 8000/8000 [==============================] - 1s 92us/step - loss: 0.3590 - accuracy: 0.8528
# Epoch 17/100
# 8000/8000 [==============================] - 1s 95us/step - loss: 0.3575 - accuracy: 0.8529
# Epoch 18/100
# 8000/8000 [==============================] - 1s 94us/step - loss: 0.3568 - accuracy: 0.8536
# Epoch 19/100
# 8000/8000 [==============================] - 1s 95us/step - loss: 0.3552 - accuracy: 0.8551
# Epoch 20/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.3541 - accuracy: 0.8554
# Epoch 21/100
# 8000/8000 [==============================] - 1s 105us/step - loss: 0.3531 - accuracy: 0.8551
# Epoch 22/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3529 - accuracy: 0.8556
# Epoch 23/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3515 - accuracy: 0.8540
# Epoch 24/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3506 - accuracy: 0.8553
# Epoch 25/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.3514 - accuracy: 0.8546
# Epoch 26/100
# 8000/8000 [==============================] - 1s 113us/step - loss: 0.3498 - accuracy: 0.8569
# Epoch 27/100
# 8000/8000 [==============================] - 1s 112us/step - loss: 0.3488 - accuracy: 0.8577
# Epoch 28/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.3480 - accuracy: 0.8561
# Epoch 29/100
# 8000/8000 [==============================] - 1s 110us/step - loss: 0.3490 - accuracy: 0.8569
# Epoch 30/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.3475 - accuracy: 0.8554
# Epoch 31/100
# 8000/8000 [==============================] - 1s 95us/step - loss: 0.3464 - accuracy: 0.8579
# Epoch 32/100
# 8000/8000 [==============================] - 1s 95us/step - loss: 0.3470 - accuracy: 0.8555
# Epoch 33/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.3463 - accuracy: 0.8570
# Epoch 34/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3461 - accuracy: 0.8570
# Epoch 35/100
# 8000/8000 [==============================] - 1s 105us/step - loss: 0.3458 - accuracy: 0.8576
# Epoch 36/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3451 - accuracy: 0.8568
# Epoch 37/100
# 8000/8000 [==============================] - 1s 99us/step - loss: 0.3445 - accuracy: 0.8579
# Epoch 38/100
# 8000/8000 [==============================] - 1s 99us/step - loss: 0.3443 - accuracy: 0.8562
# Epoch 39/100
# 8000/8000 [==============================] - 1s 115us/step - loss: 0.3449 - accuracy: 0.8576
# Epoch 40/100
# 8000/8000 [==============================] - 1s 110us/step - loss: 0.3443 - accuracy: 0.8568
# Epoch 41/100
# 8000/8000 [==============================] - 1s 98us/step - loss: 0.3444 - accuracy: 0.8586
# Epoch 42/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3439 - accuracy: 0.8574
# Epoch 43/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3444 - accuracy: 0.8576
# Epoch 44/100
# 8000/8000 [==============================] - 1s 99us/step - loss: 0.3438 - accuracy: 0.8559
# Epoch 45/100
# 8000/8000 [==============================] - 1s 99us/step - loss: 0.3438 - accuracy: 0.8571
# Epoch 46/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3445 - accuracy: 0.8565
# Epoch 47/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3440 - accuracy: 0.8564
# Epoch 48/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3429 - accuracy: 0.8584
# Epoch 49/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3434 - accuracy: 0.8568
# Epoch 50/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3428 - accuracy: 0.8599
# Epoch 51/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3430 - accuracy: 0.8551
# Epoch 52/100
# 8000/8000 [==============================] - 1s 99us/step - loss: 0.3430 - accuracy: 0.8585
# Epoch 53/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.3434 - accuracy: 0.8580
# Epoch 54/100
# 8000/8000 [==============================] - 1s 96us/step - loss: 0.3429 - accuracy: 0.8574
# Epoch 55/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.3425 - accuracy: 0.8555
# Epoch 56/100
# 8000/8000 [==============================] - 1s 96us/step - loss: 0.3433 - accuracy: 0.8585
# Epoch 57/100
# 8000/8000 [==============================] - 1s 98us/step - loss: 0.3426 - accuracy: 0.8601
# Epoch 58/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3428 - accuracy: 0.8622
# Epoch 59/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.3420 - accuracy: 0.8581
# Epoch 60/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3426 - accuracy: 0.8568
# Epoch 61/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3423 - accuracy: 0.8587
# Epoch 62/100
# 8000/8000 [==============================] - 1s 96us/step - loss: 0.3429 - accuracy: 0.8580
# Epoch 63/100
# 8000/8000 [==============================] - 1s 98us/step - loss: 0.3425 - accuracy: 0.8569
# Epoch 64/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.3427 - accuracy: 0.8571
# Epoch 65/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3419 - accuracy: 0.8595
# Epoch 66/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3432 - accuracy: 0.8574
# Epoch 67/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.3430 - accuracy: 0.8565
# Epoch 68/100
# 8000/8000 [==============================] - 1s 98us/step - loss: 0.3425 - accuracy: 0.8589
# Epoch 69/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.3423 - accuracy: 0.8596
# Epoch 70/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.3421 - accuracy: 0.8586
# Epoch 71/100
# 8000/8000 [==============================] - 1s 95us/step - loss: 0.3421 - accuracy: 0.8594
# Epoch 72/100
# 8000/8000 [==============================] - 1s 96us/step - loss: 0.3421 - accuracy: 0.8595
# Epoch 73/100
# 8000/8000 [==============================] - 1s 98us/step - loss: 0.3417 - accuracy: 0.8589
# Epoch 74/100
# 8000/8000 [==============================] - 1s 98us/step - loss: 0.3425 - accuracy: 0.8572
# Epoch 75/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.3424 - accuracy: 0.8584
# Epoch 76/100
# 8000/8000 [==============================] - 1s 98us/step - loss: 0.3420 - accuracy: 0.8591
# Epoch 77/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.3412 - accuracy: 0.8587
# Epoch 78/100
# 8000/8000 [==============================] - 1s 89us/step - loss: 0.3415 - accuracy: 0.8605
# Epoch 79/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.3420 - accuracy: 0.8558
# Epoch 80/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.3415 - accuracy: 0.8604
# Epoch 81/100
# 8000/8000 [==============================] - 1s 86us/step - loss: 0.3420 - accuracy: 0.8580
# Epoch 82/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.3413 - accuracy: 0.8577
# Epoch 83/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.3419 - accuracy: 0.8579
# Epoch 84/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.3414 - accuracy: 0.8596
# Epoch 85/100
# 8000/8000 [==============================] - 1s 123us/step - loss: 0.3414 - accuracy: 0.8590
# Epoch 86/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3412 - accuracy: 0.8591
# Epoch 87/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.3416 - accuracy: 0.8599
# Epoch 88/100
# 8000/8000 [==============================] - 1s 89us/step - loss: 0.3418 - accuracy: 0.8611
# Epoch 89/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.3417 - accuracy: 0.8576
# Epoch 90/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.3409 - accuracy: 0.8594
# Epoch 91/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.3416 - accuracy: 0.8594
# Epoch 92/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.3413 - accuracy: 0.8601
# Epoch 93/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.3407 - accuracy: 0.8572
# Epoch 94/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.3409 - accuracy: 0.8581
# Epoch 95/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.3404 - accuracy: 0.8594
# Epoch 96/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.3401 - accuracy: 0.8602
# Epoch 97/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.3405 - accuracy: 0.8608
# Epoch 98/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.3405 - accuracy: 0.8608
# Epoch 99/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.3407 - accuracy: 0.8587
# Epoch 100/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.3400 - accuracy: 0.8568
# [[1518   77]
#  [ 208  197]]
